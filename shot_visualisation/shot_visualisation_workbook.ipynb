# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import VerticalPitch

df = pd.read_csv('erling_haaland_2022_understat.csv')

# %%
df.head()
# Out:
#        id  minute       result      X      Y        xG          player h_a  \
# 0  479846      20  MissedShots  0.936  0.503  0.484085  Erling Haaland   a
# 1  479847      35         Goal  0.885  0.500  0.761169  Erling Haaland   a
# 2  479854      64         Goal  0.864  0.405  0.328053  Erling Haaland   a
# 3  479855      69  MissedShots  0.953  0.552  0.526608  Erling Haaland   a
# 4  479856      75  BlockedShot  0.894  0.710  0.066443  Erling Haaland   a
#
#    player_id situation  season  shotType  match_id    h_team           a_team  \
# 0       8260  OpenPlay    2022      Head     18211  West Ham  Manchester City
# 1       8260   Penalty    2022  LeftFoot     18211  West Ham  Manchester City
# 2       8260  OpenPlay    2022  LeftFoot     18211  West Ham  Manchester City
# 3       8260  OpenPlay    2022      Head     18211  West Ham  Manchester City
# 4       8260  OpenPlay    2022  LeftFoot     18211  West Ham  Manchester City
#
#    h_goals  a_goals                 date  player_assisted   lastAction
# 0        0        2  2022-08-07 15:30:00       Phil Foden        Cross
# 1        0        2  2022-08-07 15:30:00              NaN     Standard
# 2        0        2  2022-08-07 15:30:00  Kevin De Bruyne  Throughball
# 3        0        2  2022-08-07 15:30:00    Jack Grealish      Chipped
# 4        0        2  2022-08-07 15:30:00   Ilkay Gündogan         Pass

# %%
df['X'] = df['X']*100
df['Y'] = df['Y']*100

# %%
total_shots=df.shape[0]
total_goals=df[df['result']=='Goal'].shape[0]
total_xG= df['xG'].sum()
xG_per_shot= total_xG/total_shots
points_average_distance= df['X'].mean()
actual_average_distance = 120 - (df['X']*1.2).mean()

# %%
background_color = '#0C0D0E'

# %%
import matplotlib.font_manager as font_manager
font_props = font_manager.FontProperties(family=['monospace'])

# %%
from turtle import color
from matplotlib.font_manager import FontProperties


fig = plt.figure(figsize=(8,12))
fig.patch.set_facecolor(background_color)

ax1= fig.add_axes([0, .7, 1, .2])
ax1.set_facecolor(background_color)
ax1.set_xlim(0,1)
ax1.set_ylim(0,1)


ax1.text(
    x=.5,
    y=.85,
    s='Erling Haaland',
    fontsize=20,
    fontproperties=font_props,
    fontweight='bold',
    color='white',
    ha='center'
)

ax1.text(
    x=.5,
    y=.75,
    s='All shots in the Premier League 2022-23',
    fontsize=14,
    fontproperties=font_props,
    fontweight='bold',
    color='white',
    ha='center'
)


ax1.text(
    x=.25,
    y=.5,
    s='Low-Quality Chance',
    fontsize=12,
    fontproperties=font_props,
    fontweight='bold',
    color='white',
    ha='center'
)


ax1.scatter(
    x=.40,
    y=.53,
    s=100,
    color=background_color,
    edgecolor='white',
    linewidth=.8
)

ax1.scatter(
    x=.45,
    y=.53,
    s=200,
    color=background_color,
    edgecolor='white',
    linewidth=.8
)

ax1.scatter(
    x=.50,
    y=.53,
    s=300,
    color=background_color,
    edgecolor='white',
    linewidth=.8
)

ax1.scatter(
    x=.55,
    y=.53,
    s=400,
    color=background_color,
    edgecolor='white',
    linewidth=.8
)

ax1.scatter(
    x=.60,
    y=.53,
    s=500,
    color=background_color,
    edgecolor='white',
    linewidth=.8
)

ax1.text(
    x=.75,
    y=.5,
    s='High-Quality Chance',
    fontsize=12,
    fontproperties=font_props,
    fontweight='bold',
    color='white',
    ha='center'
)

ax1.text(
    x=.45,
    y=.27,
    s='Goal',
    fontsize=10,
    fontproperties=font_props,
    color='white',
    ha='right'
)

ax1.scatter(
    x=.47,
    y=.3,
    s=100,
    color='red',
    edgecolor='white',
    linewidth=.8,
    alpha=0.7
)


ax1.scatter(
    x=.53,
    y=.3,
    s=100,
    color=background_color,
    edgecolor='white',
    linewidth=.8
)

ax1.text(
    x=.55,
    y=.27,
    s='No Goal',
    fontsize=10,
    fontproperties=font_props,
    color='white',
    ha='left'
)

ax2= fig.add_axes([.05, .25, .9, .5])
ax2.set_facecolor(background_color)

pitch = VerticalPitch(
    pitch_type='opta',
    half=True,
    pitch_color=background_color,
    pad_bottom=.5,
    line_color='white',
    linewidth=.75,
    axis=True,
    label=True
)

pitch.draw(ax=ax2)

ax2.scatter(x=90,
            y=points_average_distance,
            s=100,
            color='white',
            linewidth=.8)

ax2.plot([90,90], [100, points_average_distance], color='white', linewidth=2)

ax2.text(
    x=90,
    y=points_average_distance - 4,
    s=f'Average Distance\n{actual_average_distance:.1f} yards',
    fontsize=10,
    fontproperties= font_props,
    color='white',
    ha='ceter'
)

ax3= fig.add_axes([0, .2, 1, .05])
ax3.set_facecolor(background_color)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 172
#     161 ax2.scatter(x=90,
#     162             y=points_average_distance,
#     163             s=100,
#     164             color='white',
#     165             linewidth=.8)
#     167 ax2.plot([90,90], [100, points_average_distance], color='white', linewidth=2)
#     169 ax2.text(
#     170     x=90,
#     171     y=points_average_distance - 4,
# --> 172     s=f'Average Distance\n{actual_average_distance:.lf} yards',
#     173     fontsize=10,
#     174     fontproperties= font_props,
#     175     color='white',
#     176     ha='ceter'
#     177 )
#     179 ax3= fig.add_axes([0, .2, 1, .05])
#     180 ax3.set_facecolor(background_color)
#
# ValueError: Format specifier missing precision
